# %% [markdown]
# # Langchain Intro
# `01_langchain_intro.ipynb`
#
# - LLM powered 어플리케이션 제작을 위한 프레임 워크

# %%
# %pip install -q langchain langchain-openai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-4.1-nano')
llm.invoke("Hello, world!")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 11, 'total_tokens': 20, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_c4c155951e', 'id': 'chatcmpl-CB9YofkuP2TMiY0J2wKmPHvKK6ZNa', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--e3c74c09-40a0-40c3-8325-acb8e6be7981-0', usage_metadata={'input_tokens': 11, 'output_tokens': 9, 'total_tokens': 20, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# 만약 우리가, 외국어로 메세지가 들어오면 한국어로 번역을 해주는 AI 를 만들고 싶다면?
msg = input('외국어를 넣으세요')

res = llm.invoke(f'한국어로 번역해줘: {msg}')

res.content
# Out:
# '안녕하세요'

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    # 채팅 세션의 전체적인 안내 사항
    SystemMessage(content='한국어를 이탈리어로 번역해줘'),
    HumanMessage(content='점심을 먹자. 뭘 먹는게 좋을까?')
]

llm.invoke(messages)
# Out:
# AIMessage(content='Andiamo a pranzo. Cosa sarebbe meglio mangiare?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 39, 'total_tokens': 52, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_e91a518ddb', 'id': 'chatcmpl-CB9ZDkDyYtgwMtGJo1OlhmboWveyj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--bb1d5b22-0f6e-4b0b-b897-356b4cf961b1-0', usage_metadata={'input_tokens': 39, 'output_tokens': 13, 'total_tokens': 52, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
messages = [
    {'role': 'system', 'content': '한국어를 이탈리어로 번역해줘'},
    {'role': 'human', 'content': '배부르다'},
]

llm.invoke(messages)
# Out:
# AIMessage(content='Sono sazio.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 4, 'prompt_tokens': 27, 'total_tokens': 31, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_c4c155951e', 'id': 'chatcmpl-CB9ZIHHTzt0fiLl4QKujdrQG7jdTT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--fc764a90-2a77-437c-ab67-fb3e919da14f-0', usage_metadata={'input_tokens': 27, 'output_tokens': 4, 'total_tokens': 31, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
for token in llm.stream(messages):
    print(token.content, end="|")
# Out:
# |Sono| sa|zio|.||

# %% [markdown]
# ## Prompt Template
# - 고정된 문자열과 변수를 조합하여 프롬프트를 만드는 방법
#
# ## Chain
# - Langchain의 각 구성요소를 묶어서(chaining) 한번에 실행(invoke)할 수 있도록 하는 기능
# - `a | b | c` 형태로 나옴. 이건 Python 문법이 아니라 Langchain 문법(LCEL-LanChain Expression Language)

# %%
# 채팅을 할 경우에는 ChatPromptTemplate
from langchain_core.prompts import ChatPromptTemplate

messages = [
    {'role': 'system', 'content': 'Translate Korean to {lang}'},
    {'role': 'human', 'content': '{text}'}
]

prompt_template = ChatPromptTemplate.from_messages(messages)

prompt = prompt_template.invoke({'lang': '일본어', 'text': '초밥이 먹고싶다'})
llm.invoke(prompt)
# Out:
# AIMessage(content='寿司が食べたいです。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 24, 'total_tokens': 32, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_c4c155951e', 'id': 'chatcmpl-CB9ZVubjumXPRWP0Tm4zhWtJmHE0S', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--1b24fa88-d5d9-42bd-9288-4268e684a4f6-0', usage_metadata={'input_tokens': 24, 'output_tokens': 8, 'total_tokens': 32, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
prompt = prompt_template.invoke({'lang': '영어', 'text': '버거가 먹고싶다'})
llm.invoke(prompt)
# Out:
# AIMessage(content='I want to eat a burger.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 22, 'total_tokens': 29, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4.1-nano-2025-04-14', 'system_fingerprint': 'fp_e91a518ddb', 'id': 'chatcmpl-CB9Zdx19LdzCMLSpcxL7Xcc3wbIyI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--240e6089-bca8-4abb-b624-cd220006d604-0', usage_metadata={'input_tokens': 22, 'output_tokens': 7, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()

# a | b | c => 
chain = prompt_template | llm | output_parser

chain.invoke({'lang': '영어', 'text': '김치찌개가 먹고싶다'})
# Out:
# 'I want to eat kimchi stew.'

# %%
# 단발성 명령 수행 PromptTemplate
from langchain_core.prompts import PromptTemplate

template = """
당신은 클라이언트 요구사항을 분석해서 단계를 나눠주는 데이터분석 전문가 입니다.
사용자의 질문을 EDA에 활용할 수 있도록 단계를 나눠주세요

질문: {question}
"""

prompt = PromptTemplate.from_template(template)

chain = prompt | llm | output_parser

res = chain.invoke({'question': '이번 2025년 전반기 매출 분석'})

print(res)
# Out:
# 2025년 전반기 매출 분석을 위한 EDA(탐색적 데이터 분석) 단계는 다음과 같이 구성할 수 있습니다:
#
# 1. 데이터 수집 및 통합
#    - 매출 관련 데이터(예: 거래 기록, 고객 정보, 상품 정보 등) 수집
#    - 다양한 출처에서 데이터를 통합 및 병합
# 2. 데이터 정제 및 전처리
#    - 결측치 및 이상치 확인 및 처리
#    - 데이터 타입 검증(숫자, 날짜 등)
#    - 필요시 데이터 변환(예: 날짜 포맷 변경)
# 3. 데이터 이해 및 개요 파악
#    - 전체 매출 추이(월별, 분기별) 파악
#    - 핵심 지표(총 매출, 고객수, 평균 주문 금액 등) 계산
#    - 매출에 영향을 미치는 주요 변수 탐색
# 4. 시각화 및 패턴 분석
#    - 시계열 그래프로 매출 추이 시각화
#    - 상품, 고객군, 지역별 매출 분포 분석
#    - 시즌별 또는 프로모션 기간과 매출의 관계 탐색
# 5. 세부 분석 및 인사이트 도출
#    - 매출이 높은 상품군 또는 고객군 분석
#    - 성과가 저조한 영역 파악
#    - 주요 매출 변화의 원인 분석
# 6. 결론 및 보고서 작성
#    - 분석 결과 요약 정리
#    - 향후 대응 전략 또는 추가 분석 필요성 제시
#
# 이 단계를 따라 진행하면 2025년 전반기 매출 트렌드와 인사이트를 체계적으로 파악할 수 있습니다.

# %%
# chain 은 Runnable 객체이기 때문에 invoke, stream, batch 메서드 사용가능
for token in chain.stream({'question': '이번 2025년 전반기 매출 분석'}):
    print(token, end='', flush=True)
# Out:
# 물론입니다. "2025년 전반기 매출 분석"을 위한 단계별 EDA(탐색적 데이터 분석) 과정을 아래와 같이 제안드립니다.
#
# 1. 데이터 수집 및 확인
#    - 매출 데이터 수집 (예: 거래 내역, 거래일, 상품 정보, 고객 정보 등)
#    - 데이터 파일 또는 시스템 접속 방법 파악
# 2. 데이터 적재 및 초기 검토
#    - 데이터 불러오기 (Excel, CSV, DB 등)
#    - 데이터 구조 파악 (칼럼명, 데이터 타입, 데이터 크기)
# 3. 데이터 전처리
#    - 결측치 및 이상치 처리
#    - 날짜 형식 통일 (연도, 월, 일 분리 또는 통합)
#    - 필요 시 데이터 정제 및 필터링 (2025년 전반기 데이터 추출)
# 4. 기초 통계 분석
#    - 전체 매출 합계, 평균, 중앙값 등 요약 통계
#    - 월별 매출 트렌드 파악 (1월~6월)
#    - 주요 상품군 또는 카테고리별 매출 분석
#    - 고객별/지역별 매출 비중 분석
# 5. 데이터 시각화
#    - 월별 매출 추이 그래프
#    - 카테고리 또는 상품별 매출 기여도 차트
#    - 고객 또는 지역별 매출 분포
# 6. 패턴 및 인사이트 도출
#    - 계절성 또는 주기성 파악
#    - 성장 또는 감소 추세 분석
#    - 주요 매출 기여 요인 식별
# 7. 추가 분석 (선택적)
#    - 고객 세분화 또는 세그먼트 분석
#    - 마케팅 캠페인 영향 분석
# 8. 결론 도출 및 보고서 작성
#    - 핵심 인사이트 정리
#    - 전략 제안 또는 다음 단계 추천
#
# 이 단계들을 따라 분석을 진행하시면 2025년 전반기 매출 현황에 대한 구체적이고 체계적인 인사이트를 얻으실 수 있습니다.

# %%
prompt = PromptTemplate.from_template('{topic}에 대해서 3문장으로 설명해줘')
llm = ChatOpenAI(model='gpt-4.1-nano')

chain = prompt | llm | StrOutputParser()

chain.batch([
    {'topic': 'Langchain'},
    {'topic': 'Langsmith'},
    {'topic': 'Langgraph'},
])
# Out:
# ['Langchain은 자연어 처리와 인공지능 애플리케이션 개발을 위한 프레임워크로, 대규모 언어 모델을 활용하여 다양한 기능을 쉽게 구축할 수 있게 도와줍니다. 주로 데이터 소스와의 통합, 사용자 쿼리 응답, 대화형 애플리케이션 개발에 초점을 맞추고 있습니다. 이를 통해 개발자는 복잡한 자연어 이해와 처리를 간단하고 효율적으로 구현할 수 있습니다.',
#  'Langsmith는 자연어 처리 기술을 활용하여 사용자와의 대화를 지원하는 인공지능 플랫폼입니다. 이 플랫폼은 맞춤형 챗봇 개발, 언어 이해 개선, 그리고 다양한 언어 기반 서비스 제공에 초점을 맞추고 있습니다. 이를 통해 기업이나 개발자들이 효율적이고 자연스러운 언어 기반 애플리케이션을 구축할 수 있도록 돕습니다.',
#  'LangGraph는 자연어 처리를 위한 그래프 기반 지식 표현 시스템으로, 언어의 의미와 관계를 그래프로 구조화하여 이해하고자 합니다. 이 시스템은 텍스트 내의 개체와 그들 간의 관계를 시각화하거나 분석하는 데 사용되며, 의미 분석과 질문응답 시스템에 활용됩니다. 또한, 복잡한 언어적 연관성을 효과적으로 파악할 수 있어 자연어 이해와 인공지능 분야에서 유용하게 이용되고 있습니다.']
